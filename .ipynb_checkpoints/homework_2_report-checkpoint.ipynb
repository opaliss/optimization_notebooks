# %% [markdown]
# # Homework #2
# ## Opal Issan.
#
# # Step Length selection - exact method.

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from homework_2_debug import find_local_minimum
from homework_2_debug import rosenbrock_fun

# %matplotlib notebook
plt.rcParams['figure.figsize'] = [10, 5] # default fig size.

# %% [markdown]
# # Note: The functions implements are found in the python module (included in the zip folder): homework_2_debug.py

# %% [markdown]
# ## Question #1:
# ### The initial alpha guess stategy I used is strategy #2 in lecture 6.

# %% [markdown]
# ## Question #2:
# ### I used $c_{1} = 1e-4$, $c_{2} = 0.9$, $\alpha_{max} = 1$ as instructed.

# %% [markdown]
# ## Question #3
# ### In line 11 I used python function random.unifrom to find the next trail value of $\alpha_{j+1}$. It will return a random number between the range of alpha_i and alpha_max using a uniform distribution.

# %% [markdown]
# ## Question #4
# ### I used hermite-based cubic interpolation.

# %% [markdown]
# ## Question #5
# ### The epsilon used for safeguard is 1e-8.

# %% [markdown]
# #### The steepest descent method applied to x0 = [1.2, 1.2]

# %%
res_1_sd = find_local_minimum(x0=[1.2, 1.2], c1=1e-4, c2=0.9, alpha=1, p=0.5, tol=1e-8, print_num=2115, method="sd", save_xk=True)
# Out:
# ***The first 6 iterations:***
#
# Iteration #0, x0 = [1.2, 1.2]
# ||gradient|| = 125.16932531574973
# f = 5.8
#
# Iteration #1, x1 = [1.10338938 1.24011513]
# ||gradient|| = 10.785743988413035
# f = 0.06197803493247483
#
# Iteration #2, x2 = [1.1127216  1.23579692]
# ||gradient|| = 1.356681740323501
# f = 0.013259557020200942
#
# Iteration #3, x3 = [1.11164808 1.23619384]
# ||gradient|| = 0.09187677807453282
# f = 0.012483989372722243
#
# Iteration #4, x4 = [1.10588964 1.22014399]
# ||gradient|| = 1.577948705663497
# f = 0.01202366815960123
#
# Iteration #5, x5 = [1.10534009 1.2203567 ]
# ||gradient|| = 0.8853098547256912
# f = 0.011298178602012746
#
# Iteration #6, x6 = [1.10462182 1.22059997]
# ||gradient|| = 0.08670518369899534
# f = 0.010962584961468652
#
# Iteration #2115, x2115 = [0.99996911 0.99994272]
# ||gradient|| = 0.0020649593289447424
# f = 2.973209187766663e-09

# %% [markdown]
# #### The steepest descent method applied to x0 = [-1.2, 1]

# %%
res_2_sd = find_local_minimum(x0=[-1.2, 1], c1=1e-4, c2=0.9, alpha=1, p=0.5, tol=1e-8, print_num=1718, method="sd")
# Out:
# ***The first 6 iterations:***
#
# Iteration #0, x0 = [-1.2, 1]
# ||gradient|| = 232.86768775422658
# f = 24.199999999999996
#
# Iteration #1, x1 = [-1.0174098   1.07452661]
# ||gradient|| = 14.357384044944745
# f = 4.225209187581896
#
# Iteration #2, x2 = [-1.03039454  1.06599994]
# ||gradient|| = 2.4488605050534566
# f = 4.124339847821593
#
# Iteration #3, x3 = [-1.02575746  1.06426667]
# ||gradient|| = 2.582669103649548
# f = 4.118305998837108
#
# Iteration #4, x4 = [-1.02741729  1.0598489 ]
# ||gradient|| = 2.455765726116967
# f = 4.112237844474334
#
# Iteration #5, x5 = [-1.02273632  1.05811613]
# ||gradient|| = 2.5923236448114597
# f = 4.106167540800254
#
# Iteration #6, x6 = [-1.02440668  1.05369075]
# ||gradient|| = 2.4489317659873278
# f = 4.1000557011036465
#
# Iteration #1718, x1718 = [1.00000689 1.0000189 ]
# ||gradient|| = 0.0022751502705660623
# f = 2.6637383395869004e-09

# %% [markdown]
# #### The newton method applied to x0 = [1.2, 1.2]

# %%
res_1_nw = find_local_minimum(x0=[1.2, 1.2], c1=1e-4, c2=0.9, alpha=1, p=0.5, tol=1e-8, print_num=7, method="newton")
# Out:
# ***The first 6 iterations:***
#
# Iteration #0, x0 = [1.2, 1.2]
# ||gradient|| = 125.16932531574973
# f = 5.8
#
# Iteration #1, x1 = [1.19591837 1.43020408]
# ||gradient|| = 0.39982008700559746
# f = 0.03838403441853445
#
# Iteration #2, x2 = [1.10930519 1.2230469 ]
# ||gradient|| = 3.856101207933418
# f = 0.017589305701565618
#
# Iteration #3, x3 = [1.06562195 1.13364191]
# ||gradient|| = 1.0188058268702358
# f = 0.004670372739015635
#
# Iteration #4, x4 = [1.01812643 1.03432561]
# ||gradient|| = 1.0561520457853693
# f = 0.0008374417690697597
#
# Iteration #5, x5 = [1.00563548 1.01114669]
# ||gradient|| = 0.08033997938304732
# f = 3.419297045642131e-05
#
# Iteration #6, x6 = [1.00017053 1.00031123]
# ||gradient|| = 0.013664061684795774
# f = 1.182769797441151e-07
#
# Iteration #7, x7 = [1.00000101 1.000002  ]
# ||gradient|| = 1.4690865482469167e-05
# f = 1.1078680184029322e-12

# %% [markdown]
# #### The newton method applied to x0 = [-1.2, 1]

# %%
res_2_nw = find_local_minimum(x0=[-1.2, 1], c1=1e-4, c2=0.9, alpha=1, p=0.5, tol=1e-8, print_num=19, method="newton")
# Out:
# ***The first 6 iterations:***
#
# Iteration #0, x0 = [-1.2, 1]
# ||gradient|| = 232.86768775422658
# f = 24.199999999999996
#
# Iteration #1, x1 = [-1.1752809   1.38067416]
# ||gradient|| = 4.639426214066643
# f = 4.731884325266611
#
# Iteration #2, x2 = [-0.92045245  0.78176447]
# ||gradient|| = 30.860498737330108
# f = 4.11674669902579
#
# Iteration #3, x3 = [-0.78418877  0.59638423]
# ||gradient|| = 10.100107935239375
# f = 3.2178058511869683
#
# Iteration #4, x4 = [-0.59109552  0.30301298]
# ||gradient|| = 16.918193965479908
# f = 2.7467040298803664
#
# Iteration #5, x5 = [-0.43626225  0.16635141]
# ||gradient|| = 8.530875655781733
# f = 2.1203213589902696
#
# Iteration #6, x6 = [-0.18840298 -0.02593853]
# ||gradient|| = 14.144201355161263
# f = 1.7897179509277066
#
# ***The last 6 iterations:***
#
# Iteration #14, x14 = [0.83864699 0.67992432]
# ||gradient|| = 8.865069058934901
# f = 0.0808116659533063
#
# Iteration #15, x15 = [0.86704975 0.75096855]
# ...

# %% [markdown]
# ## Question #6:
# plot the iterations:

# %%
# Plot the surface of rosenbrock_fun
x1 = np.linspace(-2, 2, 100)
x2 = np.linspace(-2, 2, 100)
X1, X2 = np.meshgrid(x1, x2)
f = np.zeros((len(x1), len(x2)))
for ii in range(len(x1)):
    for jj in range(len(x2)):
        f[ii, jj] = rosenbrock_fun([x1[ii], x2[jj]])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(res_1_sd[-1][0], res_1_sd[-1][1], rosenbrock_fun(res_1_sd[-1][0:2]), "o", color="black")
ax.scatter(res_1_sd[-1][2], res_1_sd[-1][3], rosenbrock_fun(res_1_sd[-1][2:4]), "o", color="black")
im = ax.contour3D(X1, X2, f, 100, cmap="cool")
fig.colorbar(im) 

#res_1_sd[-1][2:4]
 
_ = ax.set_title('Rosenbrock function, ic = [1.2, 1.2], SD.1st-2nd iteration')

_ = ax.set_xlabel('x1')
_ = ax.set_ylabel('x2')
_ = ax.set_zlabel('f')
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
fig,ax=plt.subplots(1,1)
cp = ax.contour(X1, X2, f, 200, cmap="cool")
ax.scatter(res_1_sd[-1][0], res_1_sd[-1][1], label="$x_{0}$", marker="o")
ax.scatter(res_1_sd[-1][2], res_1_sd[-1][3], label="$x_{1}$", marker="o")
ax.scatter(res_1_sd[-1][18], res_1_sd[-1][19], label="$x_{8}$", marker="o")
ax.plot([res_1_sd[-1][18], res_1_sd[-1][2]], [res_1_sd[-1][19], res_1_sd[-1][3]], 'k')
ax.plot([res_1_sd[-1][0], res_1_sd[-1][2]], [res_1_sd[-1][1], res_1_sd[-1][3]], 'k')
ax.scatter(res_1_sd[-1][100], res_1_sd[-1][101], label="$x_{99}$", marker="o")
ax.set_title('Rosenbrock function, ic = [1.2, 1.2], SD. 1st-2nd, 9th, 100th iteration')
ax.set_xlabel('$x_{1}$')
ax.set_ylabel('$x_{2}$')
_ = ax.set_xlim(0.5, 1.5)
_ = ax.set_ylim(0.5, 1.5)
_ = plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
fig.colorbar(im) 
ax.scatter(res_2_sd[-1][0], res_1_sd[-1][1], rosenbrock_fun(res_2_sd[-1][0:2]), "o", color="black")
ax.scatter(res_2_sd[-1][2], res_1_sd[-1][3], rosenbrock_fun(res_2_sd[-1][2:4]), "o", color="black")

im = ax.contour3D(X1, X2, f, 100, cmap="cool")


#res_1_sd[-1][2:4]
 
_ = ax.set_title('Rosenbrock function, ic = [-1.2, 1], SD.1st-2nd iteration')

_ = ax.set_xlabel('x1')
_ = ax.set_ylabel('x2')
_ = ax.set_zlabel('f')
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
plt.rcParams['figure.figsize'] = [10, 5] # default fig size.
fig,ax=plt.subplots(1,1)

cp = ax.contour(X1, X2, f, 50, cmap="cool")
ax.scatter(res_2_sd[-1][0], res_2_sd[-1][1], label="$x_{0}$", marker="o")
ax.scatter(res_2_sd[-1][2], res_2_sd[-1][3], label="$x_{1}$", marker="o")
ax.plot([res_2_sd[-1][0], res_2_sd[-1][2]], [res_2_sd[-1][1], res_2_sd[-1][3]], 'k')
ax.plot([res_2_sd[-1][18], res_2_sd[-1][100]], [res_2_sd[-1][19], res_2_sd[-1][101]], 'k')
ax.scatter(res_2_sd[-1][18], res_2_sd[-1][19], label="$x_{8}$", marker="o")
ax.plot([res_2_sd[-1][18], res_2_sd[-1][2]], [res_2_sd[-1][19], res_2_sd[-1][3]], 'k')
ax.scatter(res_2_sd[-1][100], res_2_sd[-1][101], label="$x_{99}$", marker="o")

ax.set_title('Rosenbrock function, ic = [-1.2, 1], SD. 1st-2nd, 9th, 100th iteration')
ax.set_xlabel('$x_{1}$')
ax.set_ylabel('$x_{2}$')
_ = ax.set_xlim(-1.5, 0.5)
_ = ax.set_ylim(0.5, 1.5)
_ = plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
fig.colorbar(im) 
ax.scatter(res_1_nw[-1][0], res_1_nw[-1][1], rosenbrock_fun(res_1_nw[-1][0:2]), "o", color="black")
ax.scatter(res_1_nw[-1][2], res_1_nw[-1][3], rosenbrock_fun(res_1_nw[-1][2:4]), "o", color="black")
im = ax.contour3D(X1, X2, f, 100, cmap="cool")


#res_1_sd[-1][2:4]
 
_ = ax.set_title('Rosenbrock function, ic = [1.2, 1.2], NW.1st-2nd iteration')

_ = ax.set_xlabel('x1')
_ = ax.set_ylabel('x2')
_ = ax.set_zlabel('f')
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
plt.rcParams['figure.figsize'] = [10, 5] # default fig size.
fig,ax=plt.subplots(1,1)

cp = ax.contour(X1, X2, f, 200, cmap="cool")

ax.plot([res_1_nw[-1][0], res_1_nw[-1][2]], [res_1_nw[-1][1], res_1_nw[-1][3]], 'k')
ax.scatter(res_1_nw[-1][0], res_1_nw[-1][1], label="$x_{0}$", marker="o")
ax.scatter(res_1_nw[-1][2], res_1_nw[-1][3], label="$x_{1}$", marker="o")
ax.scatter(res_1_nw[-1][13], res_1_nw[-1][14], label="$x_{6}$", marker="o")
ax.plot([res_1_nw[-1][13], res_1_nw[-1][2]], [res_1_nw[-1][14], res_1_nw[-1][3]], 'k')
#fig.colorbar(cp) 
ax.set_title('Rosenbrock function, ic = [1.2, 1.2], NW. 1st-2nd, 7th iteration')
ax.set_xlabel('$x_{1}$')
ax.set_ylabel('$x_{2}$')
_ = ax.set_xlim(0.5, 1.5)
_ = ax.set_ylim(0.5, 1.5)
_ = plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
fig.colorbar(im) 
ax.scatter(res_2_nw[-1][0], res_2_nw[-1][1], rosenbrock_fun(res_2_nw[-1][0:2]), "o", color="black")
ax.scatter(res_2_nw[-1][2], res_2_nw[-1][3], rosenbrock_fun(res_2_nw[-1][2:4]), "o", color="black")
im = ax.contour3D(X1, X2, f, 100, cmap="cool")


#res_1_sd[-1][2:4]
 
_ = ax.set_title('Rosenbrock function, ic = [-1.2, 1], NW.1st-2nd iteration')

_ = ax.set_xlabel('x1')
_ = ax.set_ylabel('x2')
_ = ax.set_zlabel('f')
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
plt.rcParams['figure.figsize'] = [10, 5] # default fig size.
fig,ax=plt.subplots(1,1)

cp = ax.contour(X1, X2, f, 50, cmap="cool")

ax.plot([res_2_nw[-1][0], res_2_nw[-1][2]], [res_2_nw[-1][1], res_2_nw[-1][3]], 'k')
ax.scatter(res_2_nw[-1][0], res_2_nw[-1][1], label="$x_{0}$", marker="o")
ax.scatter(res_2_nw[-1][2], res_2_nw[-1][3], label="$x_{1}$", marker="o")
ax.plot([res_2_nw[-1][13], res_2_nw[-1][38]], [res_2_nw[-1][14], res_2_nw[-1][39]], 'k')
ax.scatter(res_2_nw[-1][13], res_2_nw[-1][14], label="$x_{8}$", marker="o")
ax.plot([res_2_nw[-1][13], res_2_nw[-1][2]], [res_2_nw[-1][14], res_2_nw[-1][3]], 'k')
ax.scatter(res_2_nw[-1][38], res_2_nw[-1][39], label="$x_{18}$", marker="o")
#fig.colorbar(cp) 
ax.set_title('Rosenbrock function, ic = [-1.2, 1], NW. 1st-2nd, 9th, 19th iteration')
ax.set_xlabel('$x_{1}$')
ax.set_ylabel('$x_{2}$')
#_ = ax.set_xlim(0.5, -1.5)
#_ = ax.set_ylim(-0.5, 1.5)
_ = plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %% [markdown]
# ## Question 7
# plot the objective function as a function of the iteration number.

# %%
f_res_1_sd = np.ones(int(len(res_1_sd[-1])/2))

for ii in range(0, int(len(res_1_sd[-1])/2)):
    
    f_res_1_sd[ii] = rosenbrock_fun([res_1_sd[-1][2*ii], res_1_sd[-1][2*ii + 1]])

# %%
fig, ax = plt.subplots(1, 1)
_ = ax.scatter(np.arange(len(f_res_1_sd)), np.log10(f_res_1_sd), 2)

_ = ax.set_title("Rosenbrock function, ic = [1.2, 1.2], SD.")
_ = ax.set_xlabel("# of iterations")
_ = ax.set_ylabel("log10(f)")
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
f_res_2_sd = np.ones(int(len(res_2_sd[-1])/2))

for ii in range(0, int(len(res_2_sd[-1])/2)):
    
    f_res_2_sd[ii] = rosenbrock_fun([res_2_sd[-1][2*ii], res_2_sd[-1][2*ii + 1]])

# %%
fig, ax = plt.subplots(1, 1)
_ = ax.scatter(np.arange(len(f_res_2_sd)), np.log10(f_res_2_sd), 2)

_ = ax.set_title("Rosenbrock function, ic = [-1.2, 1], SD.")
_ = ax.set_xlabel("# of iterations")
_ = ax.set_ylabel("log10(f)")
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
f_res_1_nw = np.ones(int(len(res_1_nw[-1])/2))

for ii in range(0, int(len(res_1_nw[-1])/2)):
    
    f_res_1_nw[ii] = rosenbrock_fun([res_1_nw[-1][2*ii], res_1_nw[-1][2*ii + 1]])

# %%
fig, ax = plt.subplots(1, 1)
_ = ax.scatter(np.arange(len(f_res_1_nw)), np.log10(f_res_1_nw), 20)
_ = ax.plot(np.arange(len(f_res_1_nw)), np.log10(f_res_1_nw), 4)

_ = ax.set_title("Rosenbrock function, ic = [1.2, 1.2], NW.")
_ = ax.set_xlabel("# of iterations")
_ = ax.set_ylabel("log10(f)")
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %%
f_res_2_nw = np.ones(int(len(res_2_nw[-1])/2))

for ii in range(0, int(len(res_2_nw[-1])/2)):
    
    f_res_2_nw[ii] = rosenbrock_fun([res_2_nw[-1][2*ii], res_2_nw[-1][2*ii + 1]])

# %%
fig, ax = plt.subplots(1, 1)
_ = ax.scatter(np.arange(len(f_res_2_nw)), np.log10(f_res_2_nw), 20)
_ = ax.plot(np.arange(len(f_res_2_nw)), np.log10(f_res_2_nw), 4)

_ = ax.set_title("Rosenbrock function, ic = [-1.2, 1], NW.")
_ = ax.set_xlabel("# of iterations")
_ = ax.set_ylabel("log10(f)")
# Out:
# <img src="data:image/png;base64,..." width="998.9999702274808">

# %% [markdown]
# # Question #8:
#
# There is a significiant difference between the number of iterations it takes the algorithm to converge when using netwons method vs steepest descent.
# On the other hand, comparing the exact line search method with backtracking, the exact line search method does not improve much the number of iterations it takes netwons method to converge. For steepest descent, we see a significant improvement in the number of iteration using exact line search.
#
# From the plots above, we can observe that newtons method still converges quadradically and steepest descent converges linearly.
#
#
# A comparison between the number of iterations using backtracking vs exact line search method is in the table below:

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Table(header=dict(values=["x0" , 'SD Exact line search', 'SD backtracking', 'NW exact linesearch', 'NW backtracking']),
                 cells=dict(values=[[(1.2, 1.2), (-1.2, 1)], [2115,  1718], [7611,8299], [7, 19], [7, 20]]))
                     ])
fig.show()
# Out:
# <div>                            <div id="efec89e9-6798-42f0-a61d-a214012685a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efec89e9-6798-42f0-a61d-a214012685a4")) {                    Plotly.newPlot(                        "efec89e9-6798-42f0-a61d-a214012685a4",                        [{"cells": {"values": [[[1.2, 1.2], [-1.2, 1]], [2115, 1718], [7611, 8299], [7, 19], [7, 20]]}, "header": {"values": ["x0", "SD Exact line search", "SD backtracking", "NW exact linesearch", "NW backtracking"]}, "type": "table"}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "
# ...
